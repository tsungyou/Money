# %%
# 量縮價平/價跌
import pyarrow as pa
import pyarrow.parquet as pq
import pandas as pd
from pymongo import MongoClient
mongo = MongoClient("mongodb+srv://doadmin:12VQ3UrM70T695BL@medina-mongo-prod-4d15c7ee.mongo.ondigitalocean.com/admin?tls=true&authSource=admin")
data = mongo['PSTAGE']['securities_trading_data'].find({"日期":{"$gte":pd.to_datetime('2023-01-01')}}, {"_id":0}).limit(0)
df = pd.DataFrame(list(data))

pq.write_table(pa.Table.from_pandas(df), 'securities_trading_data.parquet')

# %%
# Out:
#         證券碼         日期     開盤價     最高價     最低價     收盤價    成交量(千股)  交易所本益比  \
# 0      0050 2024-03-01  143.55  143.95  142.80  142.80   9019.098     NaN
# 1      0050 2024-03-04  145.00  147.20  144.85  146.95  25733.539     NaN
# 2      0050 2024-03-05  147.75  148.55  147.35  148.15  17270.419     NaN
# 3      0050 2024-03-06  147.00  149.05  146.40  148.85  17232.812     NaN
# 4      0050 2024-03-07  151.00  153.00  150.75  152.30  31117.921     NaN
# ...     ...        ...     ...     ...     ...     ...        ...     ...
# 99995  1606 1981-11-09   14.30   14.40   14.20   14.35    880.000     NaN
# 99996  1607 1981-11-09   15.90   16.00   15.60   15.60     78.000     NaN
# 99997  1701 1981-11-09   19.00   19.10   18.20   19.00    773.000     NaN
# 99998  1702 1981-11-09   18.10   18.10   17.50   17.60    276.000     NaN
# 99999  1704 1981-11-09   18.70   18.90   18.00   18.90    231.000     NaN
#
#         流通股數(千股)  交易所淨值市價比   現金股利率   開盤價-除權息   最高價-除權息   最低價-除權息   收盤價-除權息  \
# ...
