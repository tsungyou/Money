# %%
import tkinter as tk
from tkinter import scrolledtext
import json

def get_collections_by_colname(colname):
    with open(cols_list_file, "r") as f:
        data = json.load(f)
    matching_strings = [item for item in data if colname in item]
    sub_dict = {key: data[key] for key in matching_strings if key in data}
    return sub_dict

def search(event=None):
    colname = entry.get()
    result = get_collections_by_colname(colname)
    output.config(state=tk.NORMAL)
    output.delete(1.0, tk.END)
    output.insert(tk.END, json.dumps(result, indent=4))
    output.config(state=tk.DISABLED)

# Path to the file containing collections list
cols_list_file = "financial_statements/cols_list.json"

# Create the main window
root = tk.Tk()
root.title("Search Collections by Column Name")

# Create a label and an entry for user input
label = tk.Label(root, text="Enter column name:")
label.pack()
entry = tk.Entry(root)
entry.pack()

# Bind the Enter key to the search function
entry.bind("<Return>", search)

# Create a button to trigger the search
button = tk.Button(root, text="Search", command=search)
button.pack()

# Create a scrolled text widget to display the result
output = scrolledtext.ScrolledText(root, width=60, height=20)
output.pack()

# Run the main event loop
root.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/tkinter/__init__.py", line 1967, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "/var/folders/zc/_sy5126x4ks5w74_nsrx_mv40000gp/T/ipykernel_98039/1515936094.py", line 14, in search
#     result = get_collections_by_colname(colname)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/zc/_sy5126x4ks5w74_nsrx_mv40000gp/T/ipykernel_98039/1515936094.py", line 6, in get_collections_by_colname
#     with open(cols_list_file, "r") as f:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/test/Library/Python/3.11/lib/python/site-packages/IPython/core/interactiveshell.py", line 324, in _modified_open
#     return io_open(file, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: 'financial_statements/cls_list.json'
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/tkinter/__init__.py", line 1967, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "/var/folders/zc/_sy5126x4ks5w74_nsrx_mv40000gp/T/ipykernel_98039/1515936094.py", line 14, in search
#     result = get_collections_by_colname(colname)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/zc/_sy5126x4ks5w74_nsrx_mv40000gp/T/ipykernel_98039/1515936094.py", line 6, in get_collections_by_colname
#     with open(cols_list_file, "r") as f:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/test/Library/Python/3.11/lib/python/site-packages/IPython/core/interactiveshell.py", line 324, in _modified_open
#     return io_open(file, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: 'financial_statements/cls_list.json'
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/tkinter/__init__.py", line 1967, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "/var/folders/zc/_sy5126x4ks5w74_nsrx_mv40000gp/T/ipykernel_98039/1515936094.py", line 14, in search
#     result = get_collections_by_colname(colname)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/zc/_sy5126x4ks5w74_nsrx_mv40000gp/T/ipykernel_98039/1515936094.py", line 6, in get_collections_by_colname
#     with open(cols_list_file, "r") as f:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/test/Library/Python/3.11/lib/python/site-packages/IPython/core/interactiveshell.py", line 324, in _modified_open
#     return io_open(file, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: 'financial_statements/cls_list.json'
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/tkinter/__init__.py", line 1967, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "/var/folders/zc/_sy5126x4ks5w74_nsrx_mv40000gp/T/ipykernel_98039/1515936094.py", line 14, in search
#     result = get_collections_by_colname(colname)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/zc/_sy5126x4ks5w74_nsrx_mv40000gp/T/ipykernel_98039/1515936094.py", line 6, in get_collections_by_colname
#     with open(cols_list_file, "r") as f:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/test/Library/Python/3.11/lib/python/site-packages/IPython/core/interactiveshell.py", line 324, in _modified_open
#     return io_open(file, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: 'financial_statements/cls_list.json'
